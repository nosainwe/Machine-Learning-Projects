# %% [markdown]
# <a href="https://colab.research.google.com/github/nosainwe/Machine-Learning-Projects/blob/main/Project_1_Credit_card_Fraud_Detection_with_Machine_learning_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading the dataset to a pandas dataframe
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
#print first 5 rows of credit card dat
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 116937  74484 -0.934006 -1.503903  1.058895 -2.361391 -2.028143 -0.363832
# 116938  74484 -3.127918  0.405786  1.898121  0.494119 -1.374594  1.513014
# 116939  74484  1.195331 -0.166388 -1.623243 -0.588598  2.262196  3.029452
# 116940  74484  1.085605 -0.145635  1.077927  1.638285 -0.472635  0.828304
# 116941  74484 -1.511932  0.687085  1.294324 -1.542139 -0.075181 -0.617780
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 116937  0.952631 -0.051021 -0.210507  ...  0.030498 -0.010490  0.865103
# 116938 -0.335495  0.243147  1.332244  ... -0.970703 -0.397175 -0.439562
# 116939 -0.062796  0.659896 -0.320458  ... -0.392730 -1.489906  0.046603
# 116940 -0.474942  0.260914  1.157265  ... -0.423978 -0.727626  0.021664
# 116941       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
#to get infromation about the dataset
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116942 entries, 0 to 116941
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    116942 non-null  int64
#  1   V1      116942 non-null  float64
#  2   V2      116942 non-null  float64
#  3   V3      116942 non-null  float64
#  4   V4      116942 non-null  float64
#  5   V5      116942 non-null  float64
#  6   V6      116942 non-null  float64
#  7   V7      116941 non-null  float64
#  8   V8      116941 non-null  float64
#  9   V9      116941 non-null  float64
#  10  V10     116941 non-null  float64
#  11  V11     116941 non-null  float64
#  12  V12     116941 non-null  float64
#  13  V13     116941 non-null  float64
#  14  V14     116941 non-null  float64
#  15  V15     116941 non-null  float64
#  16  V16     116941 non-null  float64
#  17  V17     116941 non-null  float64
#  18  V18     116941 non-null  float64
#  19  V19     116941 non-null  float64
# ...

# %%
#checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#checking the distribution of legit transaction and fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    116697
# 1.0       244
# Name: count, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced so we have to do some data preprocessing
# 0 means Normal Transaction
# 1 means Fraudulent Transaction

# %%
#Now we seperate the data for analysis into two categories
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print (legit.shape)
print (fraud.shape)
# Out:
# (116697, 31)
# (244, 31)

# %%
# statistical measures of our credit card data
legit.Amount.describe()
# Out:
# count    116697.000000
# mean         94.585514
# std         256.349273
# min           0.000000
# 25%           6.950000
# 50%          25.000000
# 75%          85.000000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     244.000000
# mean      120.047418
# std       253.594749
# min         0.000000
# 25%         1.000000
# 50%         9.560000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values for both types of transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    46570.315149 -0.242538 -0.019715  0.697015  0.145716 -0.275291
# 1.0    39556.676230 -5.909172  4.116352 -7.544907  4.687119 -4.212303
#
#              V6        V7       V8        V9  ...       V20       V21  \
# Class                                         ...
# 0.0    0.094735 -0.102174  0.05668 -0.066908  ...  0.043009 -0.037568
# 1.0   -1.518731 -6.266148  1.57925 -2.706892  ...  0.257534  1.341778
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.111817 -0.035641  0.011500  0.131620  0.026699 -0.000196  0.001996
# 1.0   -0.328776 -0.103162 -0.108318  0.201929  0.080489  0.529196  0.068036
#
#            Amount
# Class
# 0.0     94.585514
# 1.0    120.047418
#
# [2 rows x 30 columns]

# %%
# We need to deal with unbalanced data using undersampling
# We would build a sample dataset containing similar distribution of normal transactions and fraudelent transactions

# Number for fraudulent transactions = 244

legit_sample = legit.sample(n=244)

# %% [markdown]
# Concantenate 2 data frames

# %%
new_datset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_datset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 85030  60569 -0.395783  1.072267  1.210086 -0.291461  0.629518  0.091335
# 69097  53262 -0.909187  0.954915 -0.636072 -0.042454  2.194481  3.460756
# 94002  64686  1.206392 -0.500950  0.794319 -0.900769 -1.088884 -0.314759
# 37666  39054 -1.623988  0.295192  2.278234  2.067274  0.519188  0.819045
# 87462  61694 -1.118980 -0.014418  1.003283 -1.388318 -0.564135  2.021013
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 85030  0.712285  0.049101 -0.544028  ... -0.239303 -0.525817 -0.107505
# 69097 -0.407605  1.293725 -0.596649  ... -0.198990 -0.705995  0.217822
# 94002 -0.741921  0.178882  1.710941  ...  0.031911  0.254067 -0.096612
# 37666  0.235245  0.202185 -0.593654  ...  0.109711  0.494472 -0.388031
# 87462  0.974314  0.170433  0.685202  ... -0.274123 -0.389268 -0.316999
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_datset.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 111690  72327 -4.198735  0.194121 -3.917586  3.920748 -1.875486 -2.118933
# 112840  72824 -1.111495 -0.257575  2.250210  1.152671  0.432904  1.254126
# 114271  73408 -2.869795  1.335667 -1.009530  1.693885 -0.741480 -0.796773
# 116139  74159 -1.548788  1.808698 -0.953509  2.213085 -2.015728 -0.913457
# 116404  74262 -2.250535  2.365755 -2.955491  0.089791 -2.830745 -0.844462
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 111690 -3.614445  1.687884 -2.189871  ...  0.801312 -0.183001 -0.440387
# 112840 -0.584163 -0.609682  1.014602  ...  0.862913  0.927825 -0.343058
# 114271 -2.614242  1.066636 -1.135497  ...  0.528421  0.228027 -0.749298
# 116139 -2.356013  1.197169 -1.678374  ...  0.855138  0.774745  0.059037
# 116404 -0.174062 -0.407138  0.174216  ...  0.256560 -0.466245  0.291105
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_datset['Class'].value_counts()
# Out:
# Class
# 0.0    244
# 1.0    244
# Name: count, dtype: int64

# %%
# Splitting the data into Features & targets
X = new_datset.drop(columns='Class', axis=1)
Y = new_datset['Class']

# %%
print(X
    )
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 85030   60569 -0.395783  1.072267  1.210086 -0.291461  0.629518  0.091335
# 69097   53262 -0.909187  0.954915 -0.636072 -0.042454  2.194481  3.460756
# 94002   64686  1.206392 -0.500950  0.794319 -0.900769 -1.088884 -0.314759
# 37666   39054 -1.623988  0.295192  2.278234  2.067274  0.519188  0.819045
# 87462   61694 -1.118980 -0.014418  1.003283 -1.388318 -0.564135  2.021013
# ...       ...       ...       ...       ...       ...       ...       ...
# 111690  72327 -4.198735  0.194121 -3.917586  3.920748 -1.875486 -2.118933
# 112840  72824 -1.111495 -0.257575  2.250210  1.152671  0.432904  1.254126
# 114271  73408 -2.869795  1.335667 -1.009530  1.693885 -0.741480 -0.796773
# 116139  74159 -1.548788  1.808698 -0.953509  2.213085 -2.015728 -0.913457
# 116404  74262 -2.250535  2.365755 -2.955491  0.089791 -2.830745 -0.844462
#
#               V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
#Now we split the data into training data and testing data

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (488, 30) (390, 30) (98, 30)

# %%
# Model Training
# USing Logistic Regression
model = LogisticRegression()

#Training the Logistic regression Model with training Data

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Model Evaluation based on accuracy Score

# accuracy on trainiong data

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print ('Accuracy of training data: ', training_data_accuracy)
# Out:
# Accuracy of training data:  0.9512820512820512

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

print ('Accuracy score on Test Data: ', test_data_accuracy)
# Out:
# Accuracy score on Test Data:  0.9387755102040817
